# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
I want to explore how machine learning can help businesses make better commercial decisions by understanding what customers are actively searching for instead of relying only on assumptions or historical habits. My interest is in combining search demand, customer behavior, and business data to identify products with growing demand and uncover opportunities that businesses may be overlooking. My long-term goal is to use data-driven insights to help businesses improve inventory planning and marketing decisions.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
Decision: Which products should a business prioritize, stock, promote, or discontinue?

Who acts?
- Business owners
- Marketing managers,
- Inventory managers
- Retail managers

Cost of a wrong decision:
- Wrong inventory
- Lost sales
- Overstock
- Stockouts
- Wasted advertising budget
- Poor customer satisfaction
- Reduced revenue

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

df = pd.read_csv("starter.csv")

df.head()

df.describe()

df["search_volume"].mean()

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
This project is intended to support business decision-making by identifying patterns and opportunities in search and business data. The findings should be treated as decision-support rather than absolute truth. The analysis can highlight relationships and emerging trends, but it cannot prove causation or predict future customer behavior with certainty. Final business decisions should consider additional factors such as pricing, competition, seasonality, and operational constraints.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
